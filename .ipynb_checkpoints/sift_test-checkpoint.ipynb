# %%
import cv2 
import matplotlib.pyplot as plt
# reading the image
img = cv2.imread('/home/quetalasj/Downloads/low00001.png')
img2 = cv2.imread('/home/quetalasj/Documents/alena/EnlightenGAN-inference/tests/processed2.jpg')
img3 = cv2.blur(img2, (3,3))
# convert to greyscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# %%
# create SIFT feature extractor
sift = cv2.xfeatures2d.SIFT_create()

# %%
# detect features from the image
keypoints, descriptors = sift.detectAndCompute(img, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
keypoints3, descriptors3 = sift.detectAndCompute(blured, None)

# %%
# draw the detected key points
sift_image = cv2.drawKeypoints(gray, keypoints, img)
# show the image
sift_image2 = cv2.drawKeypoints(gray2, keypoints2, img2)
sift_image3 = cv2.drawKeypoints(gray3, keypoints3, img3)
plt.imshow(sift_image)
plt.show()
plt.imshow(sift_image2)
plt.show()
plt.imshow(sift_image3)
plt.show()

# %%
img = cv2.imread('/home/quetalasj/Downloads/xoford.JPG')
img2 = cv2.imread('/home/quetalasj/Documents/alena/EnlightenGAN-inference/tests/oxford_light.jpg')
img3 = cv2.blur(img2, (3,3))
# convert to greyscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

keypoints, descriptors = sift.detectAndCompute(img, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2, None)
keypoints3, descriptors3 = sift.detectAndCompute(blured, None)


# draw the detected key points
sift_image = cv2.drawKeypoints(gray, keypoints, img)
# show the image
sift_image2 = cv2.drawKeypoints(gray2, keypoints2, img2)
sift_image3 = cv2.drawKeypoints(gray3, keypoints3, img3)
plt.figure(figsize=(16,8))
plt.imshow(sift_image)
plt.show()
plt.figure(figsize=(16,8))
plt.imshow(sift_image2)
plt.show()
plt.figure(figsize=(16,8))
plt.imshow(sift_image3)
plt.show()
